# %%
import matplotlib.pyplot as plt
squares = []
for i in range(1,1000):
    squares.append(i**2)

plt.plot(range(1,1000),squares)
plt.title("Square of Numbers")
# Out:
# Text(0.5, 1.0, 'Square of Numbers')
